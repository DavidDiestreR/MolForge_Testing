# %% [markdown]
# # Fingerprints to SMILES amb MolForge (executar en l'entorn MolForge-env)
#
# 1. Llegeix el fitxer de fingerprints preprocessat amb columnes: "id" y "fingerprints".
# 2. Executa MolForge sobre els fingerprints y guarda els resultats en una nova columna "SMILES".
# 3. Guarda els resultats en `data/MolForge_output/`.

# %% [markdown]
# ## Imports

# %%
import pandas as pd

# %% [markdown]
# ## Inputs

# %% [markdown]
# Fitxer de fingerprints preprocessat (path a partir de MolForge_input/)

# %%
input_filename = "test_1.csv"

# %% [markdown]
# Fitxer en que guardar l'output (path a partir de MolForge_output/)

# %%
output_filename = "test_1_output.csv"

# %% [markdown]
# Paràmetres de MolForge

# %%
FP_NAME = "ECFP4"
MODEL_TYPE = "smiles"  # ["smiles", "selfies"]
DECODE = "greedy"  # ["greedy", "beam"]
CHECKPOINT_NAME = "ECFP4_smiles_checkpoint.pth"

# %% [markdown]
# ## 1. Lectura del fitxer

# %%
input_path = "/export/home/ddiestre/MolForge_Testing/data/MolForge_input/"

# %%
# Lectura del fitxer
df = pd.read_csv(input_path+input_filename, sep = ',', na_filter=False , index_col = 0)
df.head(5)
# Out:
#                                          fingerprints
# id
# 1   1 80 94 114 237 241 255 294 392 411 425 695 74...
# 2   97 101 314 378 389 442 501 650 728 817 896 909...
# 3   9 45 78 89 145 203 322 548 586 650 695 718 760...

# %% [markdown]
# ## 2. Execució de Molforge

# %%
print(df.columns)
# Out:
# Index(['fingerprints'], dtype='object')

# %%
print(df['fingerprints'][1])
# Out:
# 1 80 94 114 237 241 255 294 392 411 425 695 743 747 786 875 1057 1171 1238 1365 1380 1452 1544 1750 1773 1853 1873 1970

# %%
# DEFINIR RUN FOR FP I TESTEJAR

# %%
# df['SMILES'] = # Exec molforge
smiles_out = []
len_df = len(df)
for i in range(len_df): # de 0 a len_df-1
    s = run_for_fp(df['fingerprints'][i+1], FP_NAME, MODEL_TYPE, CHECKPOINT_NAME, DECODE)
    smiles_out.append((i+1, s))
    print(f"[{i}/5] id={i+1} -> {s}")

# %% [markdown]
# ## 3. Guardar l'output

# %%
output_path = "/export/home/ddiestre/MolForge_Testing/data/MolForge_output/"

# %%
df['SMILES'] = smiles_out
df.to_csv(output_path+output_filename)
